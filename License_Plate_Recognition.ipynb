# %% [markdown]
# <a href="https://colab.research.google.com/github/MYoussef885/License-Plate-Recognition/blob/main/License_Plate_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install easyocr
# %pip install imutils
# Out:
# Requirement already satisfied: easyocr in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: torch in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (2.4.1)
# Requirement already satisfied: torchvision>=0.5 in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (0.19.1)
# Requirement already satisfied: opencv-python-headless in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (4.10.0.84)
# Requirement already satisfied: scipy in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (1.14.1)
# Requirement already satisfied: numpy in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (2.1.1)
# Requirement already satisfied: Pillow in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (10.4.0)
# Requirement already satisfied: scikit-image in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (0.24.0)
# Requirement already satisfied: python-bidi in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (0.6.0)
# Requirement already satisfied: PyYAML in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (2.0.6)
# Requirement already satisfied: pyclipper in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: filelock in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from torch->easyocr) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: sympy in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from torch->easyocr) (1.13.3)
# Requirement already satisfied: networkx in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from torch->easyocr) (3.3)
# Requirement already satisfied: jinja2 in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from torch->easyocr) (3.1.4)
# Requirement already satisfied: fsspec in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from torch->easyocr) (2024.9.0)
# Requirement already satisfied: setuptools in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from torch->easyocr) (75.1.0)
# Requirement already satisfied: imageio>=2.33 in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from scikit-image->easyocr) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from scikit-image->easyocr) (2024.9.20)
# Requirement already satisfied: packaging>=21 in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from scikit-image->easyocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from jinja2->torch->easyocr) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imutils in e:\iiit-ny\license-plate-recognition\.venv\lib\site-packages (0.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %%
img = cv2.imread("image3.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17)
edged = cv2.Canny(bfilter, 30, 200)
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
  approx = cv2.approxPolyDP(contour, 10, True)
  if len(approx) == 4:
    location = approx
    break

# %%
location

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0, 255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[52], line 2
#       1 mask = np.zeros(gray.shape, np.uint8)
# ----> 2 new_image = cv2.drawContours(mask, [location], 0, 255, -1)
#       3 new_image = cv2.bitwise_and(img, img, mask=mask)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\drawing.cpp:2433: error: (-215:Assertion failed) p.checkVector(2, CV_32S) >= 0 in function 'cv::fillPoly'

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# []

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0), 3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 text = result[0][-2]
#       2 font = cv2.FONT_HERSHEY_SIMPLEX
#       3 res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
#
# IndexError: list index out of range
